# %% [markdown]
# # Exploratory Data Analysis
# ## Salaries Table

# %%
# Go One Level Up to set the Workinkg Space
import os
os.chdir("..")

# %%
# Python Libreries
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from sql_queries import read_sql

# %%
from initialization.salaries import populate_database

# %%
populate_database()

# %%
# Read Data from the States Table
salaries_df = read_sql("""--sql
    SELECT * FROM salaries
""")

# %%
salaries_df.describe()
# Out:
#             team_id    year      salaries
# count  3.000000e+01    30.0  3.000000e+01
# mean   1.610613e+09  2021.0  1.373934e+08
# std    8.803408e+00     0.0  1.889484e+07
# min    1.610613e+09  2021.0  8.202287e+07
# 25%    1.610613e+09  2021.0  1.277465e+08
# 50%    1.610613e+09  2021.0  1.359389e+08
# 75%    1.610613e+09  2021.0  1.401756e+08
# max    1.610613e+09  2021.0  1.789808e+08

# %%
salaries_df.year.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
px.line(salaries_df, x='year', y='salaries', color='team_id')
